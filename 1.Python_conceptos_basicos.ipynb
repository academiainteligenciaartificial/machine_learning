# %% [markdown]
# # **Python - Tipos de datos básicos**

# %% [markdown]
# ## Numéricos

# %%
edad = 37
type(edad)
# Out:
# int

# %%
clima = 27.5
type(clima)
# Out:
# float

# %%
variable = 1.0
type(variable)
# Out:
# float

# %%
complejo = 1 + 3j
type(complejo)
# Out:
# complex

# %% [markdown]
# ## Cadena

# %%
nombre = "Christian"
type(nombre)
# Out:
# str

# %% [markdown]
# ## Lista

# %%
nombres = ["Christian", "Juan", "John"]
nombres
# Out:
# ['Christian', 'Juan', 'John']

# %%
type(nombres)
# Out:
# list

# %%
lista_numeros = [9, 8, 6, 10, "30"]
lista_numeros
# Out:
# [9, 8, 6, 10, '30']

# %%
type(lista_numeros)
# Out:
# list

# %%
lista_global = [nombres, lista_numeros]
lista_global
# Out:
# [['Christian', 'Juan', 'John'], [9, 8, 6, 10, '30']]

# %%
type(lista_global)
# Out:
# list

# %%
nombres[1]
# Out:
# 'Juan'

# %%
lista_global[1][4]
# Out:
# '30'

# %% [markdown]
# ## Diccionario

# %%
usuario = {"nombre": "Christian", "edad": 37}
usuario
# Out:
# {'nombre': 'Christian', 'edad': 37}

# %%
usuario["nombre"]
# Out:
# 'Christian'

# %%
usuario["edad"]
# Out:
# 37
