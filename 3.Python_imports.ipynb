# %% [markdown]
# # Formas de utilizar librerías en python

# %%
import numpy

# %%
numpy.random.random()
# Out:
# 0.6674051732143711

# %%
import numpy as np
np.random.random()
# Out:
# 0.8451009119208756

# %%
import numpy.random as rd
rd.random()
# Out:
# 0.7881574032709476

# %%
from numpy.random import random
random()
# Out:
# 0.9816891937025443
