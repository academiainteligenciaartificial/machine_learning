# %% [markdown]
# # Algoritmo de regresión linear

# %%
from sklearn import datasets

# %%
X, y = datasets.make_regression(
    n_samples=100,
    n_features=1,
    noise=5,
    random_state=42
)

# %%
import matplotlib.pyplot as plt

# %%
_ ,ax = plt.subplots()
ax.scatter(X, y, alpha=0.5)
ax.set_xlabel("Caracteristicas / Features")
ax.set_ylabel("Variable objetivo / Target")
# Out:
# Text(0, 0.5, 'Variable objetivo / Target')

# %%
import numpy as np

# %%
X = np.interp(X, (X.min(), X.max()), (0, 5))

# %%
y = np.interp(y, (y.min(), y.max()), (78000, 150000))

# %%
_ ,ax = plt.subplots()
ax.scatter(X, y, alpha=0.5)
ax.set_xlabel("Años de experiencia")
ax.set_ylabel("Salario anual en $")
# Out:
# Text(0, 0.5, 'Salario anual en $')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X.shape, y.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((100, 1), (100,), (80, 1), (20, 1), (80,), (20,))

# %%
from sklearn import linear_model

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)

# %%
_ ,ax = plt.subplots()
ax.plot(X_train, y_train_pred, color='green', alpha=0.5)
ax.scatter(X, y, alpha=0.5)
ax.set_xlabel("Años de experiencia")
ax.set_ylabel("Salario anual en $")
# Out:
# Text(0, 0.5, 'Salario anual en $')

# %% [markdown]
# ## Evaluar nuestro algoritmo

# %%
y_test_pred = model.predict(X_test)

# %%
_ ,ax = plt.subplots()
ax.scatter(X_test, y_test, alpha=0.5)
ax.scatter(X_test, y_test_pred, alpha=0.5)
ax.set_xlabel("Años de experiencia")
ax.set_ylabel("Salario anual en $")
# Out:
# Text(0, 0.5, 'Salario anual en $')

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_true=y_test, y_pred=y_test_pred)
mse
# Out:
# 5056661.363050614

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 2248.7021508084645
